# %% [markdown]
# # **Importacion de Librerias**

# %%
import pandas as pd
import sqlite3
from sqlalchemy import create_engine

# %% [markdown]
# # **Lectura de CSV**

# %%
con = create_engine("sqlite://", echo=False)
df = pd.read_csv('games.csv')
df.to_sql("vg", con, if_exists="replace")
df
# Out:
#                                                 name platform  \
# 0                                 ! SPACE ACCIDENT !       PC
# 1       ! That Bastard Is Trying To Steal Our Gold !       PC
# 2                                         !4RC4N01D!       PC
# 3                        !4RC4N01D! 2: Retro Edition       PC
# 4                           !4RC4N01D! 3: Cold Space       PC
# ...                                              ...      ...
# 142412                                   {Undefined}       PC
# 142413                                  ~ Daydream ~       PC
# 142414    ~Azur Ring~virgin and slave's phylacteries       PC
# 142415                                   ~Gigantify~       PC
# 142416                    ~necromancy~Emily's Escape       PC
#
#              release_date                                            summary  \
# 0       February 10, 2022  The year is 2119. A turning point has begun in...
# 1            May 11, 2014  It's a fun puzzle game where you need to steal...
# 2        January 12, 2018  Hardcore arkanoid in the spirit of old games f...
# 3        February 6, 2018  Everyone dreams of returning 2007, but no one ...
# 4           March 8, 2018  !4RC4N01D! returns! This time we have an accid...
# ...                   ...                                                ...
# 142412    August 20, 2021  A sandbox survival game, set on life-sized vox...
# 142413       May 26, 2022  ~Daydream~is an action 2D platform jumping gam...
# 142414      July 17, 2020  New DIABLO-Like adventure game. Legendary gear...
# 142415   January 23, 2022  This is a small Puzzle Platformer where you dy...
# 142416  December 21, 2018  The necromancer employs forbidden spells and p...
#
#        metascore userscore
# 0            tbd       tbd
# 1            tbd       3.4
# 2            tbd       4.0
# 3            tbd       3.8
# 4            tbd       3.0
# ...          ...       ...
# 142412       tbd       tbd
# 142413       tbd       tbd
# 142414       tbd       tbd
# 142415       tbd       tbd
# 142416       tbd       tbd
#
# [142417 rows x 6 columns]

# %% [markdown]
# # **Limpieza de Datos**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142417 entries, 0 to 142416
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          142417 non-null  object
#  1   platform      142417 non-null  object
#  2   release_date  142417 non-null  object
#  3   summary       124702 non-null  object
#  4   metascore     142417 non-null  object
#  5   userscore     142417 non-null  object
# dtypes: object(6)
# memory usage: 6.5+ MB

# %% [markdown]
# ve si hay nulos

# %%
df.isnull().sum()
# Out:
# name                0
# platform            0
# release_date        0
# summary         17715
# metascore           0
# userscore           0
# dtype: int64

# %% [markdown]
# como son pocos se eliminan los nulos

# %%
df.dropna(inplace=True)

# %% [markdown]
# cambia tipo de variable a date

# %%
df['release_date'] = pd.to_datetime(df.release_date)
df['release_date'] = df['release_date'].dt.strftime('%Y-%m-%d')

# %% [markdown]
# se elimina el espacio para la columna platform

# %%
df['platform'] = df['platform'].str.lstrip()
df['platform'].unique()
# Out:
# array(['PC', 'Wii', 'iOS', 'PlayStation 4', 'Switch', 'Xbox One',
#        'PlayStation Vita', 'PlayStation 3', 'PlayStation 5', 'Xbox 360',
#        'PlayStation 2', 'Wii U', 'PlayStation', 'DS', 'Nintendo 64',
#        '3DS', 'PSP', 'GameCube', 'Dreamcast', 'Xbox', 'Xbox Series X',
#        'Stadia', 'Game Boy Advance'], dtype=object)

# %%
df.to_sql("vg", con, if_exists="replace")
# Out:
# 124702

# %% [markdown]
# # **Analisis de Datos**

# %% [markdown]
# ¿Cuáles son los 10 juegos más populares?

# %% [markdown]
# por metascore

# %%
consulta = '''SELECT name, summary, AVG(metascore) meta_score_avg
              FROM vg
              GROUP BY 1
              ORDER BY 3 DESC
              LIMIT 10'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#                                                 name  \
# 0                                Super Mario Odyssey
# 1                               Super Mario Galaxy 2
# 2                                 Super Mario Galaxy
# 3                                            NFL 2K1
# 4                                      Metroid Prime
# 5            The Legend of Zelda: Breath of the Wild
# 6                                    World of Goo HD
# 7                         Uncharted 2: Among Thieves
# 8                The Legend of Zelda: The Wind Waker
# 9  The House in Fata Morgana - Dreams of the Reve...
#
#                                              summary  meta_score_avg
# 0  New Evolution of Mario Sandbox-Style Gameplay....            97.0
# 1  Super Mario Galaxy 2, the sequel to the galaxy...            97.0
# 2  [Metacritic's 2007 Wii Game of the Year] The u...            97.0
# 3  In the end, NFL 2K1 is a deeper, more refined ...            97.0
# 4  Samus returns in a new mission to unravel the ...            97.0
# 5  Ignore everything you know about The Legend of...            96.5
# 6  World of Goo is a multiple award winning physi...            96.0
# 7  Fortune hunter Nathan Drake returns in Unchart...            96.0
# 8  In this ninth entry in the Legend of Zelda ser...            96.0
# 9  A gothic suspense tale set in a cursed mansion...            96.0

# %% [markdown]
# por review de usuarios

# %%
consulta = '''SELECT name, summary, ROUND(AVG(userscore),1) user_review_avg
              FROM vg
              WHERE userscore != 'tbd'
              GROUP BY 1
              ORDER BY 3 DESC
              LIMIT 10'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#                                                 name  \
# 0  Monster Hunter Rise / Monster Hunter Rise: Sun...
# 1                  Might & Magic Elemental Guardians
# 2                                    Mega Man Mobile
# 3                                          LifeAfter
# 4                  Invizimals: Battle of the Hunters
# 5                     Arcade Archives: Bubble Bobble
# 6        Z.H.P. Unlosing Ranger vs Darkdeath Evilman
# 7                                   Sneaky Sasquatch
# 8                               Resident Evil (2002)
# 9                                                OCO
#
#                                              summary  user_review_avg
# 0  Experience the entire storyline, from the Ramp...             10.0
# 1  Enter the world of Might & Magic: Elemental Gu...              9.8
# 2  It's MEGA MAN versus the powerful leaders and ...              9.8
# 3  A blizzard of devastating virus beleaguered th...              9.8
# 4  Invizimals are invisible mythical creatures ma...              9.8
# 5  THESE ARE TWO HUNGRY DINO-MIGHTS AND THEY'VE G...              9.8
# 6  Known as ZettaiHero Keikakuin Japan, Z.H.P. is...              9.7
# 7  Live the life of a Sasquatch and do regular, e...              9.7
# 8  Raccoon City has been completely overrun by mu...              9.7
# 9  Immerse yourself in the minimalist audio-visua...              9.7

# %% [markdown]
# ¿Cuáles son los 10 juegos menos populares?

# %% [markdown]
# por metascore

# %%
consulta = '''SELECT name, summary, AVG(metascore) meta_score_avg
              FROM vg
              GROUP BY 1
              ORDER BY 3
              LIMIT 10'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#                                            name  \
# 0                            ! SPACE ACCIDENT !
# 1  ! That Bastard Is Trying To Steal Our Gold !
# 2                                    !4RC4N01D!
# 3                   !4RC4N01D! 2: Retro Edition
# 4                      !4RC4N01D! 3: Cold Space
# 5                 !4RC4N01D! 4: KOHBEEP edition
# 6                                      !Anyway!
# 7                              !Arre Unicornio!
# 8                                   !BurnToDie!
# 9                       !Dead Pixels Adventure!
#
#                                              summary  meta_score_avg
# 0  The year is 2119. A turning point has begun in...             0.0
# 1  It's a fun puzzle game where you need to steal...             0.0
# 2  Hardcore arkanoid in the spirit of old games f...             0.0
# 3  Everyone dreams of returning 2007, but no one ...             0.0
# 4  !4RC4N01D! returns! This time we have an accid...             0.0
# 5  The legendary Arkanoid of your childhood is ba...             0.0
# 6  Do you like parkour? Dashing retro times? AnyW...             0.0
# 7  Arre Unicornio! is an online multiplayer video...             0.0
# 8  !BurnToDie! - Hardcore platformer, in which yo...             0.0
# 9  Dead Pixels Adventure! - A unique retro game w...             0.0

# %% [markdown]
# por review de usuarios

# %%
consulta = '''SELECT name, summary, ROUND(AVG(userscore),1) user_review_avg
              FROM vg
              WHERE userscore != 'tbd'
              GROUP BY 1
              ORDER BY 3
              LIMIT 10'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#                                                 name  \
# 0  Kingdom Hearts HD 2.8 Final Chapter Prologue C...
# 1                                           Pooplers
# 2                                       Table Tennis
# 3                        The Bullet: Time of Revenge
# 4                                        Fallen EP-1
# 5                            Paws & Claws Pet Resort
# 6           Little League World Series Baseball 2022
# 7                                 Misk Schools Quest
# 8                                            Wordify
# 9                                    Diablo Immortal
#
#                                              summary  user_review_avg
# 0  Kingdom Hearts HD 2.8 Final Chapter Prologue i...              0.0
# 1  The game is diversified by power-ups and a mot...              0.0
# 2  The desk sets the stage for this easy to enjoy...              0.0
# 3  Become a Bullet - eliminate bad people using m...              0.0
# 4  The first 2.5D Survival Horror for your iPhone...              0.2
# 5  You love animals and they love you! Care for a...              0.2
# 6  Little League World Series Baseball 2022 captu...              0.3
# 7  In the year 3020, earth became so polluted tha...              0.3
# 8  Wordify goal - using the given letters, combin...              0.3
# 9  Diablo® Immortal is a mobile Massively Multipl...              0.4

# %% [markdown]
# ¿Cuál es el mejor juego para cada plataforma?

# %% [markdown]
# por metascore

# %%
consulta = '''SELECT platform, name, summary, MAX(metascore) meta_score_max
              FROM vg
              GROUP BY 1'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#             platform                                     name  \
# 0                3DS  The Legend of Zelda: Ocarina of Time 3D
# 1                 DS         Grand Theft Auto: Chinatown Wars
# 2          Dreamcast                              SoulCalibur
# 3   Game Boy Advance  The Legend of Zelda: A Link to the Past
# 4           GameCube                            Metroid Prime
# 5        Nintendo 64     The Legend of Zelda: Ocarina of Time
# 6                 PC             Disco Elysium: The Final Cut
# 7                PSP            God of War: Chains of Olympus
# 8        PlayStation                 Tony Hawk's Pro Skater 2
# 9      PlayStation 2                 Tony Hawk's Pro Skater 3
# 10     PlayStation 3                      Grand Theft Auto IV
# 11     PlayStation 4                    Red Dead Redemption 2
# 12     PlayStation 5                                    Hades
# 13  PlayStation Vita                         Persona 4 Golden
# 14            Stadia                               Get Packed
# 15            Switch  The Legend of Zelda: Breath of the Wild
# 16               Wii                       Super Mario Galaxy
# 17             Wii U  The Legend of Zelda: Breath of the Wild
# 18              Xbox                     Halo: Combat Evolved
# 19          Xbox 360                      Grand Theft Auto IV
# 20          Xbox One                    Red Dead Redemption 2
# 21     Xbox Series X                                    Hades
#
#                                               summary  meta_score_max
# 0   The Legend of Zelda: Ocarina of Time 3D takes ...              94
# 1   Grand Theft Auto: Chinatown Wars is an entirel...              93
# 2   This is a tale of souls and swords, transcendi...              98
# 3   Now you have a link to one of the greatest adv...              95
# 4   Samus returns in a new mission to unravel the ...              97
# 5   As a young boy, Link is tricked by Ganondorf, ...              99
# 6   Disco Elysium - The Final Cut is the definitiv...              97
# 7   [Metacritic's 2008 PSP Game of the Year] Unlea...              91
# 8   As most major publishers' development efforts ...              98
# 9   Challenge up to four friends in online competi...              97
# 10  [Metacritic's 2008 PS3 Game of the Year; Also ...              98
# 11  Developed by the creators of Grand Theft Auto ...              97
# 12  Defy the god of the dead as you hack and slash...              93
# 13  Persona 4: The Golden is a remastered version ...              93
# 14  Get Packed is a couch co-op removals game with...              81
# 15  Forget everything you know about The Legend of...              97
# 16  [Metacritic's 2007 Wii Game of the Year] The u...              97
# 17  Ignore everything you know about The Legend of...              96
# 18  Enter the mysterious world of Halo, an alien p...              97
# 19  [Metacritic's 2008 Xbox 360 Game of the Year; ...              98
# 20  Developed by the creators of Grand Theft Auto ...              97
# 21  Defy the god of the dead as you hack and slash...              93

# %% [markdown]
# por review de usuarios

# %%
consulta = '''SELECT platform, name, summary, MAX(userscore) user_review_avg
              FROM vg
              WHERE userscore != 'tbd'
              GROUP BY 1'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#             platform                                         name  \
# 0                3DS             Fire Emblem Warriors: Fates Pack
# 1                 DS               Ghost Trick: Phantom Detective
# 2          Dreamcast                 Resident Evil Code: Veronica
# 3   Game Boy Advance                              Car Battler Joe
# 4           GameCube                         Resident Evil (2002)
# 5        Nintendo 64                                Banjo-Kazooie
# 6                 PC                                Resident Evil
# 7                PSP  Z.H.P. Unlosing Ranger vs Darkdeath Evilman
# 8        PlayStation                     Resident Evil 3: Nemesis
# 9      PlayStation 2                              Resident Evil 4
# 10     PlayStation 3                                     Vanquish
# 11     PlayStation 4               Arcade Archives: Bubble Bobble
# 12     PlayStation 5     Final Fantasy XIV Online: A Realm Reborn
# 13  PlayStation Vita            Under Night In-Birth Exe:Late[st]
# 14            Stadia                                     Darkwood
# 15            Switch                                 Superliminal
# 16               Wii                                   Mega Man 5
# 17             Wii U                                      Tengami
# 18              Xbox       Star Wars: Knights of the Old Republic
# 19          Xbox 360                                     Vanquish
# 20          Xbox One                   Dynasty Warriors 9 Empires
# 21     Xbox Series X                                  Wild Hearts
# 22               iOS                    Corpse Party: Blood Drive
#
#                                               summary user_review_avg
# 0   This DLC is themed around Fire Emblem Fates.\r...             9.7
# 1   Ghost Trick is a story of mystery and intrigue...             9.7
# 2   Resident Evil Code: Veronica takes up the stor...             9.5
# 3   Rampaging rogues roam the highways and byways ...             9.5
# 4   Raccoon City has been completely overrun by mu...             9.7
# 5   Trouble is brewing on Spiral Mountain! Gruntil...             9.2
# 6   Raccoon City has been completely overrun by mu...             9.8
# 7   Known as ZettaiHero Keikakuin Japan, Z.H.P. is...             9.7
# 8   A month and a half have passed since the mansi...             9.6
# 9   In Resident Evil 4 players are reacquainted wi...             9.3
# 10  Directed by Shinji Mikami, VANQUISH is a sci-f...             9.5
# 11  THESE ARE TWO HUNGRY DINO-MIGHTS AND THEY'VE G...             9.8
# 12  Take part in an epic and ever-changing FINAL F...             9.5
# 13  The best parts of Street Fighter and BlazBlue ...             9.9
# 14  Darkwood is a game about survival, exploration...             9.3
# 15  Perception is reality. Escape from a mind-bend...             9.6
# 16  Protoman has gone berserk! Destroying half the...             9.6
# 17  Set in Japan of ancient dark fairy tales, Teng...             9.6
# 18  Long before the Galactic Civil War, an epic dr...             9.1
# 19  Directed by Shinji Mikami, VANQUISH is a sci-f...             9.6
# 20  Empires, a unique "Romance of the Three Kingdo...             9.9
# 21  Master ancient tech to hunt down giant beasts ...             9.7
# 22  While some members of Kisaragi Academy's class...             9.8

# %% [markdown]
# ¿En qué años se lanzaron los juegos más populares?

# %% [markdown]
# por metascore

# %%
consulta = '''SELECT strftime('%Y', release_date) release_year, ROUND(AVG(metascore),1) meta_score_avg, COUNT(metascore) meta_score_count
              FROM vg
              GROUP BY 1
              ORDER BY 2 DESC'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#    release_year  meta_score_avg  meta_score_count
# 0          2002            56.4              1111
# 1          2001            54.0               803
# 2          2003            53.4              1182
# 3          2004            49.9              1117
# 4          2000            48.8               608
# 5          2005            48.1              1374
# 6          2006            41.0              1631
# 7          2007            35.3              1977
# 8          2008            32.8              2217
# 9          2009            30.2              2821
# 10         2010            29.2              3705
# 11         2014            25.5              3827
# 12         2013            24.2              4461
# 13         2011            23.1              4975
# 14         2012            22.9              5013
# 15         2015            22.3              4549
# 16         2016            20.7              5307
# 17         2017            15.4              7387
# 18         1999            14.7               313
# 19         2018            13.0              9587
# 20         1998            12.5               309
# 21         2019            11.2              9816
# 22         2020             9.3             13242
# 23         1997             9.2               319
# 24         2021             7.2             16266
# 25         1996             6.4               327
# 26         1994             6.4                13
# 27         2022             5.9             17246
# 28         2023             4.7              3129
# 29         1995             4.4                41
# 30         1993             0.0                 7
# 31         1992             0.0                 5
# 32         1991             0.0                 8
# 33         1990             0.0                 4
# 34         1989             0.0                 2
# 35         1988             0.0                 2
# 36         1986             0.0                 1

# %% [markdown]
# por review de usuarios

# %%
consulta = '''SELECT strftime('%Y', release_date) release_year, ROUND(AVG(userscore),2) user_review_avg, COUNT(userscore) user_review_count
              FROM vg
              WHERE userscore != 'tbd'
              GROUP BY 1
              ORDER BY 2 DESC'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#    release_year  user_review_avg  user_review_count
# 0          1999             8.14                163
# 1          1997             7.94                136
# 2          1998             7.89                145
# 3          1993             7.47                  7
# 4          2001             7.45                580
# 5          2003             7.42                912
# 6          1991             7.42                  5
# 7          2000             7.40                417
# 8          1990             7.38                  4
# 9          2004             7.36                827
# 10         2002             7.32                817
# 11         2005             7.28                963
# 12         1995             7.23                 37
# 13         1992             7.20                  4
# 14         1994             7.16                 10
# 15         2006             7.12               1066
# 16         2007             6.93               1199
# 17         2008             6.90               1233
# 18         1996             6.90                271
# 19         2010             6.88               1430
# 20         2009             6.87               1367
# 21         2021             6.68               1956
# 22         2012             6.66               1685
# 23         2011             6.64               1538
# 24         2017             6.63               2192
# 25         2020             6.62               2167
# 26         2018             6.61               2415
# 27         2015             6.58               2140
# 28         2016             6.54               2166
# 29         2019             6.52               2268
# 30         2014             6.50               1917
# 31         2013             6.47               1730
# 32         2023             6.45                140
# 33         2022             6.44               1354
# 34         1988             5.90                  2
# 35         1989             5.00                  1

# %% [markdown]
# ¿Qué plataformas tenían los juegos más populares?

# %% [markdown]
# por metascore

# %%
consulta = '''SELECT platform plataforma, ROUND(AVG(metascore),1) meta_score_avg, COUNT(metascore) meta_score_count
              FROM vg
              GROUP BY 1
              ORDER BY 2 DESC'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#           plataforma  meta_score_avg  meta_score_count
# 0          Dreamcast            71.8               144
# 1        Nintendo 64            71.1                94
# 2               Xbox            67.3               861
# 3           GameCube            64.9               545
# 4        PlayStation            63.1               277
# 5      PlayStation 2            57.4              1816
# 6   Game Boy Advance            51.8               750
# 7                PSP            44.3               922
# 8           Xbox 360            43.0              2885
# 9      PlayStation 3            33.8              3049
# 10               3DS            29.0              1270
# 11             Wii U            27.9               776
# 12               Wii            27.0              2022
# 13                DS            26.9              2348
# 14  PlayStation Vita            25.1              1107
# 15               iOS            24.8              9603
# 16     PlayStation 4            23.1              8528
# 17          Xbox One            23.0              6219
# 18     Xbox Series X            21.6              1371
# 19            Switch            20.5              9221
# 20     PlayStation 5            18.7              1916
# 21                PC             7.5             68666
# 22            Stadia             2.6               312

# %% [markdown]
# por review de usuarios

# %%
consulta = '''SELECT platform plataforma, ROUND(AVG(userscore),2) user_review_avg, COUNT(userscore) user_review_count
              FROM vg
              WHERE userscore != 'tbd'
              GROUP BY 1
              ORDER BY 2 DESC'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#           plataforma  user_review_avg  user_review_count
# 0          Dreamcast             7.81                138
# 1        Nintendo 64             7.61                 94
# 2        PlayStation             7.59                224
# 3      PlayStation 2             7.52               1550
# 4           GameCube             7.46                483
# 5   Game Boy Advance             7.38                505
# 6               Xbox             7.21                709
# 7                PSP             7.07                695
# 8             Stadia             7.05                219
# 9   PlayStation Vita             7.04                612
# 10                DS             6.90                820
# 11               Wii             6.89               1080
# 12            Switch             6.86               2570
# 13               3DS             6.85                579
# 14             Wii U             6.83                349
# 15          Xbox 360             6.77               2147
# 16                PC             6.76              12334
# 17     PlayStation 3             6.70               1963
# 18     Xbox Series X             6.53                389
# 19          Xbox One             6.46               2291
# 20               iOS             6.43               1441
# 21     PlayStation 5             6.40                480
# 22     PlayStation 4             6.20               3592

# %% [markdown]
# ¿Que tiene mas popularidad las consolas domesticas, portatiles, hibridas o el pc?

# %% [markdown]
# por metascore

# %%
consulta = '''SELECT CASE WHEN platform in ('3DS', 'DS', 'Game Boy Advance', 'PSP', 'PlayStation Vita') then 'portatiles'
                          WHEN platform = 'Switch' THEN 'Hibrida'
                          WHEN platform = 'PC' THEN 'PC' ELSE 'Domestica'
                          END plataforma,
                     ROUND(AVG(metascore),1) meta_score_avg, COUNT(metascore) meta_score_count
              FROM vg
              GROUP BY 1
              ORDER BY 2 DESC'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#    plataforma  meta_score_avg  meta_score_count
# 0  portatiles            32.4              6397
# 1   Domestica            29.2             40418
# 2     Hibrida            20.5              9221
# 3          PC             7.5             68666

# %% [markdown]
# por review de usuarios

# %%
consulta = '''SELECT CASE WHEN platform in ('3DS', 'DS', 'Game Boy Advance', 'PSP', 'PlayStation Vita') then 'portatiles'
                          WHEN platform = 'Switch' THEN 'Hibrida'
                          WHEN platform = 'PC' THEN 'PC' ELSE 'Domestica'
                          END plataforma,
                      ROUND(AVG(userscore),2) user_review_avg, COUNT(userscore) user_review_count
              FROM vg
              WHERE userscore != 'tbd'
              GROUP BY 1
              ORDER BY 2 DESC'''
data = pd.read_sql_query(consulta, con)
data
# Out:
#    plataforma  user_review_avg  user_review_count
# 0  portatiles             7.03               3211
# 1     Hibrida             6.86               2570
# 2          PC             6.76              12334
# 3   Domestica             6.70              17149
